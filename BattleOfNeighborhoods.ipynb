# %% [markdown]
# ## Import modules

# %%
import numpy as np

import pandas as pd
from pandas.io.json import json_normalize
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('max_colwidth', 1600)

import re
import requests

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt

#!conda install -c conda-forge folium=0.5.0 --yes
#import folium # map rendering library

# !conda install -c conda-forge geopy --yes
import geopy.geocoders                     # convert an address into latitude and longitude values
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# geopy                     1.18.1                     py_0    conda-forge

# %% [markdown]
# ## Areas of London

# %%
areas_df = pd.read_html('https://en.wikipedia.org/wiki/List_of_areas_of_London', header=0)[1]
areas_df.head()
# Out:
#       Location                     London borough       Post town  \
# 0   Abbey Wood                       Greenwich[1]          LONDON
# 1        Acton  Ealing, Hammersmith and Fulham[2]          LONDON
# 2    Addington                         Croydon[2]         CROYDON
# 3   Addiscombe                         Croydon[2]         CROYDON
# 4  Albany Park                             Bexley  BEXLEY, SIDCUP
#
#   Postcode district Dial code OS grid ref
# 0               SE2       020    TQ465785
# 1            W3, W4       020    TQ205805
# 2               CR0       020    TQ375645
# 3               CR0       020    TQ345665
# 4         DA5, DA14       020    TQ478728

# %% [markdown]
# ### Column names

# %%
areas_df.columns = areas_df.columns.str.replace('[^a-zA-Z]', '_')
areas_df.head()
# Out:
#       Location                     London_borough       Post_town  \
# 0   Abbey Wood                       Greenwich[1]          LONDON
# 1        Acton  Ealing, Hammersmith and Fulham[2]          LONDON
# 2    Addington                         Croydon[2]         CROYDON
# 3   Addiscombe                         Croydon[2]         CROYDON
# 4  Albany Park                             Bexley  BEXLEY, SIDCUP
#
#   Postcode_district Dial_code OS_grid_ref
# 0               SE2       020    TQ465785
# 1            W3, W4       020    TQ205805
# 2               CR0       020    TQ375645
# 3               CR0       020    TQ345665
# 4         DA5, DA14       020    TQ478728

# %% [markdown]
# ### Get rid of comments in London_borough column

# %%
areas_df['London_borough'].replace(to_replace='\[.*\]' ,value='', inplace=True, regex=True)
areas_df.head(10)
# Out:
#            Location                  London_borough       Post_town  \
# 0        Abbey Wood                       Greenwich          LONDON
# 1             Acton  Ealing, Hammersmith and Fulham          LONDON
# 2         Addington                         Croydon         CROYDON
# 3        Addiscombe                         Croydon         CROYDON
# 4       Albany Park                          Bexley  BEXLEY, SIDCUP
# 5  Aldborough Hatch                       Redbridge          ILFORD
# 6           Aldgate                            City          LONDON
# 7           Aldwych                     Westminster          LONDON
# 8          Alperton                           Brent         WEMBLEY
# 9           Anerley                         Bromley          LONDON
#
#   Postcode_district Dial_code OS_grid_ref
# 0               SE2       020    TQ465785
# 1            W3, W4       020    TQ205805
# 2               CR0       020    TQ375645
# 3               CR0       020    TQ345665
# 4         DA5, DA14       020    TQ478728
# 5               IG2       020    TQ455895
# 6               EC3       020    TQ334813
# 7               WC2       020    TQ307810
# 8               HA0       020    TQ185835
# 9              SE20       020    TQ345695

# %% [markdown]
# Now let's note that some locations belong to more than one borough, e.g., `Acton` belongs to boroughs `Ealing` and `Hammersmith and Fulham`. We want to break down such locations to separate entries, so we need to split `London_borough`. Looking at the wiki page, we see that we have following potential separators: `,`, `&`, `and`. Yet, some borough names sontain `and` word, so let's look at entries with `,`, `&`, `and` in `London_borough` column closer.

# %%
areas_df[areas_df.London_borough.str.contains(',| and |&')]
# Out:
#                                            Location  \
# 1                                             Acton
# 19                                          Barking
# 31                                        Becontree
# 32                                  Becontree Heath
# 68                                         Brompton
# 83                                     Castle Green
# 85                                   Chadwell Heath
# 91                                          Chelsea
# 99                                         Chiswick
# 102                                         Clapham
# 104                                     Cockfosters
# 119                                      Creekmouth
# 121                                     Cricklewood
# 131                                        Dagenham
# 143                                     Earls Court
# 169                                      Farringdon
# 173                                   Finsbury Park
# 183                                          Fulham
# 209                                     Hammersmith
# 243                                    Holland Park
# 260                                      Kennington
# 262                                      Kensington
# 264                                          Kenton
# 268                                         Kilburn
# 269                                    King's Cross
# 300                                      Marks Gate
# 318                                    Muswell Hill
# 337                                North Kensington
# 345                                    Notting Hill
# 351                                  Old Oak Common
# 358                                      Park Royal
# 359                                   Parsons Green
# 379                                      Queensbury
# 391                                      Rush Green
# 392                                          Ruxley
# 394                                       Sands End
# 401                                 Shepherd's Bush
# 409                                     Snaresbrook
# 416                                South Kensington
# 448                                         Sudbury
# 454  Sydenham (also Lower Sydenham, Upper Sydenham)
# 455                                   Sydenham Hill
# 457                                          Temple
# 459                                      Thamesmead
# 479                                    Upper Ruxley
# 499                                   West Brompton
# 509                                 West Kensington
# 515                                      White City
# 529                                  Worcester Park
# 530                                 Wormwood Scrubs
#
#                                     London_borough  \
# 1                   Ealing, Hammersmith and Fulham
# 19                            Barking and Dagenham
# 31                            Barking and Dagenham
# 32                            Barking and Dagenham
# 68   Kensington and Chelsea,Hammersmith and Fulham
# 83                            Barking and Dagenham
# 85                 Redbridge, Barking and Dagenham
# 91                          Kensington and Chelsea
# 99        Hounslow, Ealing, Hammersmith and Fulham
# 102                            Lambeth, Wandsworth
# 104                                Barnet, Enfield
# 119                           Barking and Dagenham
# 121                          Barnet, Brent, Camden
# 131                           Barking and Dagenham
# 143                         Kensington and Chelsea
# 169                               Islington & City
# 173                            Haringey, Islington
# 183                         Hammersmith and Fulham
# 209                         Hammersmith and Fulham
# 243                         Kensington and Chelsea
# 260                             Lambeth, Southwark
# 262                         Kensington and Chelsea
# 264                                  Brent, Harrow
# 268                                  Brent, Camden
# 269                           Camden and Islington
# 300                           Barking and Dagenham
# 318                            Haringey and Barnet
# 337                         Kensington and Chelsea
# 345                         Kensington and Chelsea
# 351                         Hammersmith and Fulham
# 358                                  Brent, Ealing
# 359                         Hammersmith and Fulham
# 379                                  Harrow, Brent
# 391                           Barking and Dagenham
# 392                                Bexley, Bromley
# 394                         Hammersmith and Fulham
# 401                         Hammersmith and Fulham
# 409                      Redbridge, Waltham Forest
# 416                         Kensington and Chelsea
# 448                          Brent, Ealing, Harrow
# 454                              Lewisham, Bromley
# 455                            Lewisham, Southwark
# 457                              City, Westminster
# 459                              Bexley, Greenwich
# 479                                Bexley, Bromley
# 499                         Kensington and Chelsea
# 509                         Hammersmith and Fulham
# 515                         Hammersmith and Fulham
# 529                   Sutton, Kingston upon Thames
# 530                         Hammersmith and Fulham
#
#                              Post_town Postcode_district   Dial_code  \
# 1                               LONDON            W3, W4         020
# 19                             BARKING              IG11         020
# 31                            DAGENHAM               RM9         020
# 32                            DAGENHAM               RM8         020
# 68                              LONDON               SW3         020
# 83                            DAGENHAM               RM9         020
# 85                             ROMFORD               RM6         020
# 91                              LONDON               SW3         020
# 99                              LONDON                W4         020
# 102                             LONDON               SW4         020
# 104                             BARNET               EN4         020
# 119                            BARKING              IG11         020
# 121                             LONDON               NW2         020
# 131                           DAGENHAM         RM9, RM10         020
# 143                             LONDON         SW5, SW10         020
# 169                             LONDON               EC1         020
# 173                             LONDON                N4         020
# 183                             LONDON               SW6         020
# 209                             LONDON                W6         020
# 243                             LONDON      W8, W11, W14         020
# 260                             LONDON              SE11         020
# 262                             LONDON               SW7         020
# 264                             HARROW               HA3         020
# 268                             LONDON               NW6         020
# 269                             LONDON               WC1         020
# 300                            ROMFORD               RM6         020
# 318                             LONDON               N10         020
# 337                             LONDON          W10, W11         020
# 345                             LONDON               W11         020
# 351                             LONDON              NW10         020
# 358                             LONDON              NW10         020
# 359                             LONDON               SW6         020
# 379  HARROW, STANMORE, EDGWARE, LONDON     HA3, HA7, HA8         020
# 391                            ROMFORD               RM7         020
# 392                  SIDCUP, ORPINGTON         DA14, BR5  020, 01689
# 394                             LONDON               SW6         020
# 401                             LONDON               W12         020
# 409                             LONDON               E11         020
# 416                             LONDON     SW7, SW3, SW5         020
# 448                    HARROW, WEMBLEY          HA0, HA1         020
# 454                             LONDON              SE26         020
# 455                             LONDON        SE21, SE26         020
# 457                             LONDON          EC4, WC2         020
# 459                      LONDON, ERITH   SE28, SE2, DA18         020
# 479                  SIDCUP, ORPINGTON         DA14, BR5  020, 01689
# 499                             LONDON              SW10         020
# 509                             LONDON               W14         020
# 515                             LONDON               W12         020
# 529                     WORCESTER PARK               KT4         020
# 530                             LONDON               W12         020
#
#     OS_grid_ref
# 1      TQ205805
# 19     TQ440840
# 31     TQ485855
# 32     TQ493871
# 68     TQ275795
# 83     TQ475837
# 85     TQ485885
# 91     TQ275775
# 99     TQ205785
# 102    TQ295755
# 104    TQ275965
# 119    TQ457820
# 121    TQ235855
# 131    TQ485845
# 143    TQ254784
# 169    TQ315818
# 173    TQ314872
# 183    TQ245765
# 209    TQ233786
# 243    TQ246798
# 260    TQ305775
# 262    TQ255795
# 264    TQ175885
# 268    TQ245835
# 269    TQ315835
# 300    TQ485905
# 318    TQ287897
# 337    TQ255795
# 345    TQ245805
# 351    TQ216823
# 358    TQ195828
# 359    TQ255765
# 379    TQ185895
# 391    TQ505875
# 392    TQ485704
# 394    TQ265765
# 401    TQ235798
# 409    TQ395895
# 416    TQ265785
# 448    TQ165852
# 454    TQ352714
# 455    TQ352714
# 457    TQ311809
# 459    TQ475805
# 479      TQ4970
# 499    TQ253779
# 509    TQ246783
# 515    TQ233807
# 529    TQ225655
# 530    TQ225815

# %% [markdown]
# The above shows that all `and`s are part of borough names (`Hammersmith and Fulham`, `Barking and Dagenham`, `Kensington and Chelsea`), except these two cases:
# * `Camden and Islington`
# * `Haringey and Barnet`
#
# Commas and ampersand (`Islington & City`), on the other hand, are indeed borough names separators, so let's do the split.

# %%
# first fix "Camden and Islington" and "Haringey and Barnet"
areas_df['London_borough'] = areas_df['London_borough'].str.replace('Camden and Islington', 'Camden,Islington')
areas_df['London_borough'] = areas_df['London_borough'].str.replace('Haringey and Barnet', 'Haringey,Barnet')

# then do the split
areas_split_df = pd.DataFrame(columns=['Location', 'London_borough'])
for index, row in areas_df.iterrows():
    location = row['Location']
    boroughs = re.sub(" *, *| +& +", ",", row['London_borough'])
    if "," in boroughs:
        for borough in boroughs.split(","):
            areas_split_df = areas_split_df.append({'Location': location + " (" + borough + ")", 'London_borough': borough}, ignore_index=True)
    else:
        areas_split_df = areas_split_df.append({'Location': location, 'London_borough': boroughs}, ignore_index=True)
areas_split_df.head(10)
# Out:
#                          Location          London_borough
# 0                      Abbey Wood               Greenwich
# 1                  Acton (Ealing)                  Ealing
# 2  Acton (Hammersmith and Fulham)  Hammersmith and Fulham
# 3                       Addington                 Croydon
# 4                      Addiscombe                 Croydon
# 5                     Albany Park                  Bexley
# 6                Aldborough Hatch               Redbridge
# 7                         Aldgate                    City
# 8                         Aldwych             Westminster
# 9                        Alperton                   Brent

# %% [markdown]
# Do we have duplicate location names?

# %%
duplicates = areas_split_df['Location'].duplicated(keep=False) == True
areas_split_df[duplicates]
# Out:
#        Location        London_borough
# 38      Belmont                Harrow
# 39      Belmont                Sutton
# 105  Church End                 Brent
# 106  Church End                Barnet
# 118      Coombe               Croydon
# 119      Coombe  Kingston upon Thames
# 208  Grove Park              Hounslow
# 209  Grove Park              Lewisham
# 242       Hayes               Bromley
# 243       Hayes            Hillingdon
# 385    Plaistow                Newham
# 386    Plaistow               Bromley

# %% [markdown]
# Let's fix those duplicates.

# %%
for loc in areas_split_df[areas_split_df['Location'].duplicated(keep=False) == True]['Location'].index:
    areas_split_df.loc[loc, 'Location'] = areas_split_df.loc[loc, 'Location'] + ' (' + areas_split_df.loc[loc, 'London_borough'] + ')'
areas_split_df[duplicates]
# Out:
#                           Location        London_borough
# 38                Belmont (Harrow)                Harrow
# 39                Belmont (Sutton)                Sutton
# 105             Church End (Brent)                 Brent
# 106            Church End (Barnet)                Barnet
# 118               Coombe (Croydon)               Croydon
# 119  Coombe (Kingston upon Thames)  Kingston upon Thames
# 208          Grove Park (Hounslow)              Hounslow
# 209          Grove Park (Lewisham)              Lewisham
# 242                Hayes (Bromley)               Bromley
# 243             Hayes (Hillingdon)            Hillingdon
# 385              Plaistow (Newham)                Newham
# 386             Plaistow (Bromley)               Bromley

# %% [markdown]
# ## London boroughs from Wikipedia

# %%
boroughs_df = pd.read_html('https://en.wikipedia.org/wiki/List_of_London_boroughs', header=0, encoding = 'utf-8-sig')[0]
boroughs_df.head(10)
# Out:
#                          Borough       Inner Status  \
# 0  Barking and Dagenham [note 1]         NaN    NaN
# 1                         Barnet         NaN    NaN
# 2                         Bexley         NaN    NaN
# 3                          Brent         NaN    NaN
# 4                        Bromley         NaN    NaN
# 5                         Camden           Y    NaN
# 6                        Croydon         NaN    NaN
# 7                         Ealing         NaN    NaN
# 8                        Enfield         NaN    NaN
# 9             Greenwich [note 2]  Y [note 3]  Royal
#
#                                Local authority Political control  \
# 0  Barking and Dagenham London Borough Council            Labour
# 1                Barnet London Borough Council      Conservative
# 2                Bexley London Borough Council      Conservative
# 3                 Brent London Borough Council            Labour
# 4               Bromley London Borough Council      Conservative
# 5                Camden London Borough Council            Labour
# 6               Croydon London Borough Council            Labour
# 7                Ealing London Borough Council            Labour
# 8               Enfield London Borough Council            Labour
# 9             Greenwich London Borough Council            Labour
#
#                                       Headquarters  Area (sq mi)  \
# 0                         Town Hall, 1 Town Square         13.93
# 1  North London Business Park, Oakleigh Road South         33.49
# 2                  Civic Offices, 2 Watling Street         23.38
# 3                Brent Civic Centre, Engineers Way         16.70
# 4                    Civic Centre, Stockwell Close         57.97
# 5                    Camden Town Hall, Judd Street          8.40
# 6              Bernard Weatherill House, Mint Walk         33.41
# 7              Perceval House, 14-16 Uxbridge Road         21.44
# 8                      Civic Centre, Silver Street         31.74
# 9            Woolwich Town Hall, Wellington Street         18.28
#
#    Population (2013 est)[1]  \
# 0                    194352
# 1                    369088
# 2                    236687
# 3                    317264
# 4                    317899
# 5                    229719
# 6                    372752
# 7                    342494
# 8                    320524
# 9                    264008
#
#                                                                              Co-ordinates  \
# 0  51°33′39″N 0°09′21″E﻿ / ﻿51.5607°N 0.1557°E﻿ / 51.5607; 0.1557﻿ (Barking and Dagenham)
# 1               51°37′31″N 0°09′06″W﻿ / ﻿51.6252°N 0.1517°W﻿ / 51.6252; -0.1517﻿ (Barnet)
# 2                51°27′18″N 0°09′02″E﻿ / ﻿51.4549°N 0.1505°E﻿ / 51.4549; 0.1505﻿ (Bexley)
# 3                51°33′32″N 0°16′54″W﻿ / ﻿51.5588°N 0.2817°W﻿ / 51.5588; -0.2817﻿ (Brent)
# 4               51°24′14″N 0°01′11″E﻿ / ﻿51.4039°N 0.0198°E﻿ / 51.4039; 0.0198﻿ (Bromley)
# 5               51°31′44″N 0°07′32″W﻿ / ﻿51.5290°N 0.1255°W﻿ / 51.5290; -0.1255﻿ (Camden)
# 6              51°22′17″N 0°05′52″W﻿ / ﻿51.3714°N 0.0977°W﻿ / 51.3714; -0.0977﻿ (Croydon)
# 7               51°30′47″N 0°18′32″W﻿ / ﻿51.5130°N 0.3089°W﻿ / 51.5130; -0.3089﻿ (Ealing)
# 8              51°39′14″N 0°04′48″W﻿ / ﻿51.6538°N 0.0799°W﻿ / 51.6538; -0.0799﻿ (Enfield)
# 9             51°29′21″N 0°03′53″E﻿ / ﻿51.4892°N 0.0648°E﻿ / 51.4892; 0.0648﻿ (Greenwich)
#
#    Nr. in map
# 0          25
# 1          31
# 2          23
# 3          12
# 4          20
# 5          11
# 6          19
# 7          13
# 8          30
# 9          22

# %% [markdown]
# Let's do some clean-up

# %%
# first remove notes from borough names
boroughs_df['Borough'].replace(to_replace='\[note.*$' ,value='', inplace=True, regex=True)
boroughs_df['Borough'] = boroughs_df['Borough'].str.strip()
boroughs_df.head(10)
# Out:
#                 Borough       Inner Status  \
# 0  Barking and Dagenham         NaN    NaN
# 1                Barnet         NaN    NaN
# 2                Bexley         NaN    NaN
# 3                 Brent         NaN    NaN
# 4               Bromley         NaN    NaN
# 5                Camden           Y    NaN
# 6               Croydon         NaN    NaN
# 7                Ealing         NaN    NaN
# 8               Enfield         NaN    NaN
# 9             Greenwich  Y [note 3]  Royal
#
#                                Local authority Political control  \
# 0  Barking and Dagenham London Borough Council            Labour
# 1                Barnet London Borough Council      Conservative
# 2                Bexley London Borough Council      Conservative
# 3                 Brent London Borough Council            Labour
# 4               Bromley London Borough Council      Conservative
# 5                Camden London Borough Council            Labour
# 6               Croydon London Borough Council            Labour
# 7                Ealing London Borough Council            Labour
# 8               Enfield London Borough Council            Labour
# 9             Greenwich London Borough Council            Labour
#
#                                       Headquarters  Area (sq mi)  \
# 0                         Town Hall, 1 Town Square         13.93
# 1  North London Business Park, Oakleigh Road South         33.49
# 2                  Civic Offices, 2 Watling Street         23.38
# 3                Brent Civic Centre, Engineers Way         16.70
# 4                    Civic Centre, Stockwell Close         57.97
# 5                    Camden Town Hall, Judd Street          8.40
# 6              Bernard Weatherill House, Mint Walk         33.41
# 7              Perceval House, 14-16 Uxbridge Road         21.44
# 8                      Civic Centre, Silver Street         31.74
# 9            Woolwich Town Hall, Wellington Street         18.28
#
#    Population (2013 est)[1]  \
# 0                    194352
# 1                    369088
# 2                    236687
# 3                    317264
# 4                    317899
# 5                    229719
# 6                    372752
# 7                    342494
# 8                    320524
# 9                    264008
#
#                                                                              Co-ordinates  \
# 0  51°33′39″N 0°09′21″E﻿ / ﻿51.5607°N 0.1557°E﻿ / 51.5607; 0.1557﻿ (Barking and Dagenham)
# 1               51°37′31″N 0°09′06″W﻿ / ﻿51.6252°N 0.1517°W﻿ / 51.6252; -0.1517﻿ (Barnet)
# 2                51°27′18″N 0°09′02″E﻿ / ﻿51.4549°N 0.1505°E﻿ / 51.4549; 0.1505﻿ (Bexley)
# 3                51°33′32″N 0°16′54″W﻿ / ﻿51.5588°N 0.2817°W﻿ / 51.5588; -0.2817﻿ (Brent)
# 4               51°24′14″N 0°01′11″E﻿ / ﻿51.4039°N 0.0198°E﻿ / 51.4039; 0.0198﻿ (Bromley)
# 5               51°31′44″N 0°07′32″W﻿ / ﻿51.5290°N 0.1255°W﻿ / 51.5290; -0.1255﻿ (Camden)
# 6              51°22′17″N 0°05′52″W﻿ / ﻿51.3714°N 0.0977°W﻿ / 51.3714; -0.0977﻿ (Croydon)
# 7               51°30′47″N 0°18′32″W﻿ / ﻿51.5130°N 0.3089°W﻿ / 51.5130; -0.3089﻿ (Ealing)
# 8              51°39′14″N 0°04′48″W﻿ / ﻿51.6538°N 0.0799°W﻿ / 51.6538; -0.0799﻿ (Enfield)
# 9             51°29′21″N 0°03′53″E﻿ / ﻿51.4892°N 0.0648°E﻿ / 51.4892; 0.0648﻿ (Greenwich)
#
#    Nr. in map
# 0          25
# 1          31
# 2          23
# 3          12
# 4          20
# 5          11
# 6          19
# 7          13
# 8          30
# 9          22

# %%
# next add population density
boroughs_df['Population density (ppl/sq. ml)'] = (boroughs_df['Population (2013 est)[1]'] / boroughs_df['Area (sq mi)']).round(2)
boroughs_df.head()
# Out:
#                 Borough Inner Status  \
# 0  Barking and Dagenham   NaN    NaN
# 1                Barnet   NaN    NaN
# 2                Bexley   NaN    NaN
# 3                 Brent   NaN    NaN
# 4               Bromley   NaN    NaN
#
#                                Local authority Political control  \
# 0  Barking and Dagenham London Borough Council            Labour
# 1                Barnet London Borough Council      Conservative
# 2                Bexley London Borough Council      Conservative
# 3                 Brent London Borough Council            Labour
# 4               Bromley London Borough Council      Conservative
#
#                                       Headquarters  Area (sq mi)  \
# 0                         Town Hall, 1 Town Square         13.93
# 1  North London Business Park, Oakleigh Road South         33.49
# 2                  Civic Offices, 2 Watling Street         23.38
# 3                Brent Civic Centre, Engineers Way         16.70
# 4                    Civic Centre, Stockwell Close         57.97
#
#    Population (2013 est)[1]  \
# 0                    194352
# 1                    369088
# 2                    236687
# 3                    317264
# 4                    317899
#
#                                                                              Co-ordinates  \
# 0  51°33′39″N 0°09′21″E﻿ / ﻿51.5607°N 0.1557°E﻿ / 51.5607; 0.1557﻿ (Barking and Dagenham)
# 1               51°37′31″N 0°09′06″W﻿ / ﻿51.6252°N 0.1517°W﻿ / 51.6252; -0.1517﻿ (Barnet)
# 2                51°27′18″N 0°09′02″E﻿ / ﻿51.4549°N 0.1505°E﻿ / 51.4549; 0.1505﻿ (Bexley)
# 3                51°33′32″N 0°16′54″W﻿ / ﻿51.5588°N 0.2817°W﻿ / 51.5588; -0.2817﻿ (Brent)
# 4               51°24′14″N 0°01′11″E﻿ / ﻿51.4039°N 0.0198°E﻿ / 51.4039; 0.0198﻿ (Bromley)
#
#    Nr. in map  Population density (ppl/sq. ml)
# 0          25                         13952.05
# 1          31                         11020.84
# 2          23                         10123.48
# 3          12                         18997.84
# 4          20                          5483.85

# %%
# remove junk from coordinates
boroughs_df['Co-ordinates'].replace(to_replace=['^.*/ ', ' \(.*'] ,value=['', ''], inplace=True, regex=True)
boroughs_df.head()
# Out:
#                 Borough Inner Status  \
# 0  Barking and Dagenham   NaN    NaN
# 1                Barnet   NaN    NaN
# 2                Bexley   NaN    NaN
# 3                 Brent   NaN    NaN
# 4               Bromley   NaN    NaN
#
#                                Local authority Political control  \
# 0  Barking and Dagenham London Borough Council            Labour
# 1                Barnet London Borough Council      Conservative
# 2                Bexley London Borough Council      Conservative
# 3                 Brent London Borough Council            Labour
# 4               Bromley London Borough Council      Conservative
#
#                                       Headquarters  Area (sq mi)  \
# 0                         Town Hall, 1 Town Square         13.93
# 1  North London Business Park, Oakleigh Road South         33.49
# 2                  Civic Offices, 2 Watling Street         23.38
# 3                Brent Civic Centre, Engineers Way         16.70
# 4                    Civic Centre, Stockwell Close         57.97
#
#    Population (2013 est)[1]       Co-ordinates  Nr. in map  \
# 0                    194352   51.5607; 0.1557﻿          25
# 1                    369088  51.6252; -0.1517﻿          31
# 2                    236687   51.4549; 0.1505﻿          23
# 3                    317264  51.5588; -0.2817﻿          12
# 4                    317899   51.4039; 0.0198﻿          20
#
#    Population density (ppl/sq. ml)
# 0                         13952.05
# 1                         11020.84
# 2                         10123.48
# 3                         18997.84
# 4                          5483.85

# %%
# and split coordinates
boroughs_df[['Latitude', 'Longtitude']] = boroughs_df['Co-ordinates'].str.split('; ', expand=True)
# remove BOM and convert to float
boroughs_df['Latitude'] = boroughs_df['Latitude'].str.replace('\ufeff', '').astype(float)
boroughs_df['Longtitude'] = boroughs_df['Longtitude'].str.replace('\ufeff', '').astype(float)
boroughs_df.head()
# Out:
#                 Borough Inner Status  \
# 0  Barking and Dagenham   NaN    NaN
# 1                Barnet   NaN    NaN
# 2                Bexley   NaN    NaN
# 3                 Brent   NaN    NaN
# 4               Bromley   NaN    NaN
#
#                                Local authority Political control  \
# 0  Barking and Dagenham London Borough Council            Labour
# 1                Barnet London Borough Council      Conservative
# 2                Bexley London Borough Council      Conservative
# 3                 Brent London Borough Council            Labour
# 4               Bromley London Borough Council      Conservative
#
#                                       Headquarters  Area (sq mi)  \
# 0                         Town Hall, 1 Town Square         13.93
# 1  North London Business Park, Oakleigh Road South         33.49
# 2                  Civic Offices, 2 Watling Street         23.38
# 3                Brent Civic Centre, Engineers Way         16.70
# 4                    Civic Centre, Stockwell Close         57.97
#
#    Population (2013 est)[1]       Co-ordinates  Nr. in map  \
# 0                    194352   51.5607; 0.1557﻿          25
# 1                    369088  51.6252; -0.1517﻿          31
# 2                    236687   51.4549; 0.1505﻿          23
# 3                    317264  51.5588; -0.2817﻿          12
# 4                    317899   51.4039; 0.0198﻿          20
#
#    Population density (ppl/sq. ml)  Latitude  Longtitude
# 0                         13952.05   51.5607      0.1557
# 1                         11020.84   51.6252     -0.1517
# 2                         10123.48   51.4549      0.1505
# 3                         18997.84   51.5588     -0.2817
# 4                          5483.85   51.4039      0.0198

# %%
# leave only needed columns
boroughs_df = boroughs_df[['Borough', 'Latitude', 'Longtitude', 'Population density (ppl/sq. ml)']]
boroughs_df.head()
# Out:
#                 Borough  Latitude  Longtitude  Population density (ppl/sq. ml)
# 0  Barking and Dagenham   51.5607      0.1557                         13952.05
# 1                Barnet   51.6252     -0.1517                         11020.84
# 2                Bexley   51.4549      0.1505                         10123.48
# 3                 Brent   51.5588     -0.2817                         18997.84
# 4               Bromley   51.4039      0.0198                          5483.85

# %% [markdown]
# ## Check validity of boroughs in areas dataframe

# %%
boroughs = boroughs_df['Borough'].tolist()
boroughs.append('City') # The City of London is the 33rd principal division of Greater London but it is not a London borough.
for index, row in areas_split_df.iterrows():
    borough = row['London_borough']
    if not borough in boroughs:
        print('Warning: "%s" is invalid borough' % borough)
# Out:
# Warning: "Dartford" is invalid borough

# %% [markdown]
# `Dartford` formally belongs to Kent, not London. Let's drop invalid entry.

# %%
areas_split_df = areas_split_df[areas_split_df['London_borough'] != "Dartford"]

# %% [markdown]
# ## GFR (General fertility rate) dataset

# %%
gfr_df = pd.read_csv('https://raw.githubusercontent.com/alllexx88/Coursera_Capstone/94e04598753242c7970d559ed4db92889100ae95/london-births-fertility-rates-borough-2017.csv')
print('dataset shape:', gfr_df.shape)
gfr_df.head()
# Out:
# dataset shape: (32, 2)
#                 Borough   GFR
# 0  Barking and Dagenham  82.6
# 1                Barnet  64.3
# 2                Bexley  63.3
# 3                 Brent  74.5
# 4               Bromley  66.7

# %% [markdown]
# Let's check validity of borough names, like we did for areas dataset.

# %%
for index, row in gfr_df.iterrows():
    borough = row['Borough']
    if not borough in boroughs:
        print('Warning: "%s" is invalid borough' % borough)
# Out:
# Warning: "Hackney and City of London" is invalid borough

# %% [markdown]
# Looks like `Hackney` and `City of Londond` are counted as one in the birth-rate dataset, hence let's rename `Hackney` and `City` boroughs to `Hackney and City of London` in the areas dataset. While we're at it, let's rename column `London_borough` to `Borough`, for future joining.

# %%
areas_split_df.rename(index=str, columns={'London_borough': 'Borough'}, inplace=True)
areas_split_df['Borough'] = areas_split_df['Borough'].str.replace('City|Hackney', 'Hackney and City of London')
areas_split_df[areas_split_df['Borough'] == 'Hackney and City of London']
# Out:
#               Location                     Borough
# 7              Aldgate  Hackney and City of London
# 19            Barbican  Hackney and City of London
# 50         Blackfriars  Hackney and City of London
# 141            Dalston  Hackney and City of London
# 179  Farringdon (City)  Hackney and City of London
# 211            Hackney  Hackney and City of London
# 212    Hackney Central  Hackney and City of London
# 213    Hackney Marshes  Hackney and City of London
# 214       Hackney Wick  Hackney and City of London
# 216         Haggerston  Hackney and City of London
# 256           Homerton  Hackney and City of London
# 263             Hoxton  Hackney and City of London
# 293         Lea Bridge  Hackney and City of London
# 308      Lower Clapton  Hackney and City of London
# 313        Manor House  Hackney and City of London
# 418        Shacklewell  Hackney and City of London
# 423         Shoreditch  Hackney and City of London
# 433      South Hackney  Hackney and City of London
# 458      Stamford Hill  Hackney and City of London
# 462    Stoke Newington  Hackney and City of London
# 481      Temple (City)  Hackney and City of London
# 502      Upper Clapton  Hackney and City of London
# 530       West Hackney  Hackney and City of London

# %% [markdown]
# ## Areas coordinates using geopy

# %%
def retrieve_geocode_london(location_string):
    import geopy.geocoders
    geopy.geocoders.options.default_user_agent = "my-application"
    geolocator = geopy.geocoders.Yandex()
    location = None
    address = location_string + ', London, UK'
    while location is None:
        location = geolocator.geocode(address)
    return location.latitude, location.longitude

# %%
# this csv was generated by repeatedly calling the cycle below: load it for faster execution
areas_coord_df = pd.read_csv('https://raw.githubusercontent.com/alllexx88/Coursera_Capstone/d29b5662742e07d974da60abd3afbfd0f0c62ff1/london-locations-coord.csv')

# join with main areas dataframe
areas_split_df = pd.merge(areas_split_df, areas_coord_df, how='left', on='Location')

df_len = areas_split_df.shape[0]
for i, j in enumerate(areas_split_df.iterrows()):
    index = j[0]
    row = j[1]
    if (not 'Latitude' in areas_split_df.columns) or np.isnan(areas_split_df.loc[index, 'Latitude']):
        latitude, longtitude = retrieve_geocode_london(row['Location'])
        areas_split_df.loc[index, 'Latitude'] = latitude
        areas_split_df.loc[index, 'Longtitude'] = longtitude
    if (i + 1) % 10 == 0:
        print('{}/{} completed - {}'.format(i + 1, df_len, row['Location']))
# Out:
# 10/560 completed - Alperton
# 20/560 completed - Barbican
# 30/560 completed - Bayswater
# 40/560 completed - Belmont (Sutton)
# 50/560 completed - Blackfen
# 60/560 completed - Bowes Park
# 70/560 completed - Brompton (Kensington and Chelsea)
# 80/560 completed - Canary Wharf
# 90/560 completed - Chalk Farm
# 100/560 completed - Chinbrook
# 110/560 completed - Clerkenwell
# 120/560 completed - Coombe (Kingston upon Thames)
# 130/560 completed - Cricklewood (Brent)
# 140/560 completed - Custom House
# 150/560 completed - Dulwich
# 160/560 completed - East Wickham
# 170/560 completed - Eltham
# 180/560 completed - Feltham
# 190/560 completed - Fortis Green
# 200/560 completed - Goddington
# 210/560 completed - Gunnersbury
# 220/560 completed - Hammersmith
# 230/560 completed - Harlington
# 240/560 completed - Hatton
# 250/560 completed - Highgate
# 260/560 completed - Horn Park
# 270/560 completed - Kenley
# 280/560 completed - Kidbrooke
# 290/560 completed - Lambeth
# 300/560 completed - Leytonstone
# 310/560 completed - Loxford
# 320/560 completed - Merton Park
# 330/560 completed - Mortlake
# 340/560 completed - New Eltham
# 350/560 completed - North End
# 360/560 completed - Norwood Green
# 370/560 completed - Osterley
# 380/560 completed - Perivale
# 390/560 completed - Pratt's Bottom
# 400/560 completed - Rayners Lane
# 410/560 completed - Ruxley (Bexley)
# 420/560 completed - Shepherd's Bush
# 430/560 completed - Soho
# 440/560 completed - South Woodford
# 450/560 completed - St Margarets
# 460/560 completed - Stepney
# 470/560 completed - Sudbury (Harrow)
# 480/560 completed - Teddington
# 490/560 completed - Tooting Bec
# 500/560 completed - Upminster
# 510/560 completed - Uxbridge
# 520/560 completed - Wealdstone
# 530/560 completed - West Hackney
# 540/560 completed - Westminster
# 550/560 completed - Woodford
# 560/560 completed - Yiewsley

# %%
areas_split_df.tail(10)
# Out:
#                                   Location                 Borough   Latitude  \
# 550                         Woodford Green               Redbridge  51.602595
# 551                              Woodlands                Hounslow  51.464699
# 552                               Woodside                 Croydon  51.387497
# 553                          Woodside Park                  Barnet  51.618026
# 554                               Woolwich               Greenwich  51.487138
# 555                Worcester Park (Sutton)                  Sutton  51.382697
# 556  Worcester Park (Kingston upon Thames)    Kingston upon Thames  51.382697
# 557                        Wormwood Scrubs  Hammersmith and Fulham  51.507351
# 558                                Yeading              Hillingdon  51.521565
# 559                               Yiewsley              Hillingdon  51.515496
#
#      Longtitude
# 550    0.046191
# 551   -0.328882
# 552   -0.065784
# 553   -0.185071
# 554    0.063394
# 555   -0.243488
# 556   -0.243488
# 557   -0.127660
# 558   -0.393184
# 559   -0.472882

# %% [markdown]
# ## POIs (places of interest) for each London location

# %%
# The code was removed by Watson Studio for sharing.

# %%
VERSION = '20180605' # Foursquare API version
LIMIT = 100

# %%
def getNearbyVenueCategories(names, latitudes, longtitudes, radius=500):
    count_len = names.shape[0]
    venues_list=[]
    for i, j in enumerate(zip(names, latitudes, longtitudes)):
        name = j[0]
        lat  = j[1]
        lng  = j[2]
        
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
        # make the GET request
        try:
            results = requests.get(url).json()["response"]['groups'][0]['items']
                    # return only relevant information for each nearby venue
            venues_list.append([(
                name, 
                lat, 
                lng, 
                v['venue']['name'], 
                v['venue']['location']['lat'], 
                v['venue']['location']['lng'],  
                re.search('categories_v2/(.*)/', v['venue']['categories'][0]['icon']['prefix'], re.IGNORECASE).group(1)) for v in results])              
        except:
            venues_list.append([(
                name, 
                lat, 
                lng, 
                np.nan, 
                np.nan, 
                np.nan,  
                np.nan)])
        if (i + 1) % 50 == 0:
            print('{} of {} completed'.format(i + 1, count_len))
                
        


    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
venues_df = getNearbyVenueCategories(names=areas_split_df['Location'],
                                     latitudes=areas_split_df['Latitude'],
                                     longtitudes=areas_split_df['Longtitude'],
                                     radius=1000
                                    )
print('Shape: {}'.format(venues_df.shape))
venues_df.head(10)
# Out:
# 50 of 560 completed
# 100 of 560 completed
# 150 of 560 completed
# 200 of 560 completed
# 250 of 560 completed
# 300 of 560 completed
# 350 of 560 completed
# 400 of 560 completed
# 450 of 560 completed
# 500 of 560 completed
# 550 of 560 completed
# Shape: (27494, 7)
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0   Abbey Wood              51.487621                 0.11405
# 1   Abbey Wood              51.487621                 0.11405
# 2   Abbey Wood              51.487621                 0.11405
# 3   Abbey Wood              51.487621                 0.11405
# 4   Abbey Wood              51.487621                 0.11405
# 5   Abbey Wood              51.487621                 0.11405
# 6   Abbey Wood              51.487621                 0.11405
# 7   Abbey Wood              51.487621                 0.11405
# 8   Abbey Wood              51.487621                 0.11405
# 9   Abbey Wood              51.487621                 0.11405
#
#                               Venue  Venue Latitude  Venue Longitude  \
# 0                       Sainsbury's       51.492824         0.120724
# 1                      Lesnes Abbey       51.489526         0.125839
# 2                        Co-op Food       51.487650         0.113490
# 3                        Co-op Food       51.494124         0.112796
# 4  Abbey Wood Railway Station (ABW)       51.491049         0.119893
# 5           Abbey Wood Caravan Club       51.485502         0.120014
# 6                       Bean @ Work       51.491172         0.120649
# 7                        Costcutter       51.491287         0.120938
# 8                     Bostall Woods       51.480026         0.115305
# 9                   Meghna Tandoori       51.485709         0.101681
#
#        Venue Category
# 0               shops
# 1  arts_entertainment
# 2               shops
# 3               shops
# 4              travel
# 5      parks_outdoors
# 6                food
# 7               shops
# 8      parks_outdoors
# 9                food

# %% [markdown]
# One-hot encode venues dataframe.

# %%
venues_onehot_df = pd.get_dummies(venues_df[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
venues_onehot_df['Neighborhood'] = venues_df['Neighborhood'] 

# move neighborhood column to the first column
venues_onehot_df = venues_onehot_df[[venues_onehot_df.columns[-1]] + list(venues_onehot_df.columns[:-1])]

venues_onehot_df.head()
# Out:
#   Neighborhood  arts_entertainment  building  education  event  food  \
# 0   Abbey Wood                   0         0          0      0     0
# 1   Abbey Wood                   1         0          0      0     0
# 2   Abbey Wood                   0         0          0      0     0
# 3   Abbey Wood                   0         0          0      0     0
# 4   Abbey Wood                   0         0          0      0     0
#
#    nightlife  parks_outdoors  shops  travel
# 0          0               0      1       0
# 1          0               0      0       0
# 2          0               0      1       0
# 3          0               0      1       0
# 4          0               0      0       1

# %% [markdown]
# Group venues by neighborhood and sum over categories.

# %%
venues_grouped_df = venues_onehot_df.groupby('Neighborhood').sum().reset_index()
venues_grouped_df.head()
# Out:
#                      Neighborhood  arts_entertainment  building  education  \
# 0                      Abbey Wood                   1         0          0
# 1                  Acton (Ealing)                   1         3          0
# 2  Acton (Hammersmith and Fulham)                   2         0          0
# 3                       Addington                   0         0          0
# 4                      Addiscombe                   0         0          0
#
#    event  food  nightlife  parks_outdoors  shops  travel
# 0      0     2          0               2      4       1
# 1      0    23          8               3     12       7
# 2      0     6          1               1      5       3
# 3      0     3          0               1      2       1
# 4      0     7          2               5      6       3

# %% [markdown]
# ## Merge areas and venues dataframes and group by boroughs

# %%
joint_boroughs_df = pd.merge(areas_split_df, venues_grouped_df, left_on = 'Location', right_on = 'Neighborhood', how='inner')
joint_boroughs_df.drop(['Neighborhood', 'Location', 'Latitude', 'Longtitude'], axis=1, inplace=True)
joint_boroughs_df = joint_boroughs_df.groupby('Borough').sum().reset_index()
joint_boroughs_df
# Out:
#                        Borough  arts_entertainment  building  education  \
# 0         Barking and Dagenham                12.0      10.0        0.0
# 1                       Barnet               123.0      59.0        2.0
# 2                       Bexley               161.0      32.0        0.0
# 3                        Brent                34.0      25.0        1.0
# 4                      Bromley                78.0      44.0        0.0
# 5                       Camden               197.0      46.0        0.0
# 6                      Croydon                47.0       8.0        0.0
# 7                       Ealing                42.0      23.0        1.0
# 8                      Enfield                33.0      13.0        0.0
# 9                    Greenwich                77.0      16.0        1.0
# 10  Hackney and City of London               181.0      58.0        0.0
# 11      Hammersmith and Fulham                55.0      29.0        0.0
# 12                    Haringey                59.0      44.0        0.0
# 13                      Harrow                 7.0      18.0        0.0
# 14                    Havering                35.0       6.0        0.0
# 15                  Hillingdon                 9.0      11.0        0.0
# 16                    Hounslow                24.0      22.0        0.0
# 17                   Islington               106.0      44.0        0.0
# 18      Kensington and Chelsea                71.0      15.0        2.0
# 19        Kingston upon Thames                11.0      15.0        0.0
# 20                     Lambeth                47.0      29.0        1.0
# 21                    Lewisham                67.0      40.0        0.0
# 22                      Merton                32.0      13.0        0.0
# 23                      Newham                45.0      26.0        0.0
# 24                   Redbridge                15.0      11.0        0.0
# 25        Richmond upon Thames                81.0      22.0        0.0
# 26                   Southwark                67.0      47.0        2.0
# 27                      Sutton                 3.0       7.0        0.0
# 28               Tower Hamlets               146.0      73.0        0.0
# 29              Waltham Forest                46.0      15.0        0.0
# 30                  Wandsworth                26.0      27.0        1.0
# 31                 Westminster               210.0      65.0        0.0
#
#     event   food  nightlife  parks_outdoors  shops  travel
# 0     0.0   79.0       24.0            22.0   60.0    16.0
# 1     0.0  664.0       82.0           113.0  270.0   107.0
# 2     0.0  479.0      106.0           110.0  235.0    90.0
# 3     0.0  375.0       54.0            55.0  186.0    81.0
# 4     1.0  504.0      135.0            85.0  218.0    81.0
# 5     0.0  860.0      198.0           107.0  252.0   101.0
# 6     0.0  197.0       38.0            60.0  106.0    51.0
# 7     1.0  268.0       53.0            47.0   88.0    43.0
# 8     0.0  189.0       43.0            42.0  110.0    40.0
# 9     0.0  240.0       76.0            68.0  143.0    63.0
# 10    0.0  903.0      287.0           136.0  246.0   101.0
# 11    0.0  480.0       91.0            41.0  170.0    56.0
# 12    0.0  466.0      111.0            72.0  165.0    61.0
# 13    0.0  140.0       16.0            29.0   68.0    22.0
# 14    0.0  209.0       43.0            50.0   91.0    35.0
# 15    0.0  117.0       35.0            15.0   99.0    38.0
# 16    0.0  185.0       44.0            50.0  126.0    66.0
# 17    0.0  782.0      236.0            97.0  181.0    60.0
# 18    0.0  489.0       68.0            45.0  148.0    62.0
# 19    0.0  183.0       49.0            22.0   82.0    27.0
# 20    0.0  441.0      155.0            58.0  105.0    31.0
# 21    0.0  430.0      117.0            70.0  255.0    74.0
# 22    0.0  208.0       40.0            35.0   88.0    41.0
# 23    0.0  232.0       50.0            50.0  164.0    94.0
# 24    1.0  151.0       27.0            18.0  105.0    26.0
# 25    0.0  394.0      109.0           125.0  163.0    69.0
# 26    0.0  510.0      174.0            78.0  153.0    59.0
# 27    0.0   56.0       20.0             9.0   48.0     9.0
# 28    0.0  748.0      187.0           181.0  230.0   117.0
# 29    0.0  182.0       41.0            32.0   80.0    35.0
# 30    0.0  383.0      134.0            36.0  124.0    35.0
# 31    0.0  932.0      174.0           165.0  262.0   192.0

# %% [markdown]
# Add in population density

# %%
joint_boroughs_df['population_density'] = boroughs_df['Population density (ppl/sq. ml)']
joint_boroughs_df
# Out:
#                        Borough  arts_entertainment  building  education  \
# 0         Barking and Dagenham                12.0      10.0        0.0
# 1                       Barnet               123.0      59.0        2.0
# 2                       Bexley               161.0      32.0        0.0
# 3                        Brent                34.0      25.0        1.0
# 4                      Bromley                78.0      44.0        0.0
# 5                       Camden               197.0      46.0        0.0
# 6                      Croydon                47.0       8.0        0.0
# 7                       Ealing                42.0      23.0        1.0
# 8                      Enfield                33.0      13.0        0.0
# 9                    Greenwich                77.0      16.0        1.0
# 10  Hackney and City of London               181.0      58.0        0.0
# 11      Hammersmith and Fulham                55.0      29.0        0.0
# 12                    Haringey                59.0      44.0        0.0
# 13                      Harrow                 7.0      18.0        0.0
# 14                    Havering                35.0       6.0        0.0
# 15                  Hillingdon                 9.0      11.0        0.0
# 16                    Hounslow                24.0      22.0        0.0
# 17                   Islington               106.0      44.0        0.0
# 18      Kensington and Chelsea                71.0      15.0        2.0
# 19        Kingston upon Thames                11.0      15.0        0.0
# 20                     Lambeth                47.0      29.0        1.0
# 21                    Lewisham                67.0      40.0        0.0
# 22                      Merton                32.0      13.0        0.0
# 23                      Newham                45.0      26.0        0.0
# 24                   Redbridge                15.0      11.0        0.0
# 25        Richmond upon Thames                81.0      22.0        0.0
# 26                   Southwark                67.0      47.0        2.0
# 27                      Sutton                 3.0       7.0        0.0
# 28               Tower Hamlets               146.0      73.0        0.0
# 29              Waltham Forest                46.0      15.0        0.0
# 30                  Wandsworth                26.0      27.0        1.0
# 31                 Westminster               210.0      65.0        0.0
#
#     event   food  nightlife  parks_outdoors  shops  travel  population_density
# 0     0.0   79.0       24.0            22.0   60.0    16.0            13952.05
# 1     0.0  664.0       82.0           113.0  270.0   107.0            11020.84
# 2     0.0  479.0      106.0           110.0  235.0    90.0            10123.48
# 3     0.0  375.0       54.0            55.0  186.0    81.0            18997.84
# 4     1.0  504.0      135.0            85.0  218.0    81.0             5483.85
# 5     0.0  860.0      198.0           107.0  252.0   101.0            27347.50
# 6     0.0  197.0       38.0            60.0  106.0    51.0            11156.90
# 7     1.0  268.0       53.0            47.0   88.0    43.0            15974.53
# 8     0.0  189.0       43.0            42.0  110.0    40.0            10098.42
# 9     0.0  240.0       76.0            68.0  143.0    63.0            14442.45
# 10    0.0  903.0      287.0           136.0  246.0   101.0            34969.97
# 11    0.0  480.0       91.0            41.0  170.0    56.0            28228.28
# 12    0.0  466.0      111.0            72.0  165.0    61.0            23063.57
# 13    0.0  140.0       16.0            29.0   68.0    22.0            12487.02
# 14    0.0  209.0       43.0            50.0   91.0    35.0             5584.31
# 15    0.0  117.0       35.0            15.0   99.0    38.0             6420.55
# 16    0.0  185.0       44.0            50.0  126.0    66.0            12142.85
# 17    0.0  782.0      236.0            97.0  181.0    60.0            37572.65
# 18    0.0  489.0       68.0            45.0  148.0    62.0            33246.58
# 19    0.0  183.0       49.0            22.0   82.0    27.0            11598.96
# 20    0.0  441.0      155.0            58.0  105.0    31.0            30332.24
# 21    0.0  430.0      117.0            70.0  255.0    74.0            21089.17
# 22    0.0  208.0       40.0            35.0   88.0    41.0            13996.07
# 23    0.0  232.0       50.0            50.0  164.0    94.0            22763.02
# 24    1.0  151.0       27.0            18.0  105.0    26.0            13235.63
# 25    0.0  394.0      109.0           125.0  163.0    69.0             8631.71
# 26    0.0  510.0      174.0            78.0  153.0    59.0            26792.10
# 27    0.0   56.0       20.0             9.0   48.0     9.0            11572.00
# 28    0.0  748.0      187.0           181.0  230.0   117.0            35765.40
# 29    0.0  182.0       41.0            32.0   80.0    35.0            17731.62
# 30    0.0  383.0      134.0            36.0  124.0    35.0            23470.60
# 31    0.0  932.0      174.0           165.0  262.0   192.0            27363.21

# %% [markdown]
# ## Merge with GFR dataframe

# %%
joint_boroughs_df = pd.merge(joint_boroughs_df, gfr_df, how='inner', on='Borough')
joint_boroughs_df
# Out:
#                        Borough  arts_entertainment  building  education  \
# 0         Barking and Dagenham                12.0      10.0        0.0
# 1                       Barnet               123.0      59.0        2.0
# 2                       Bexley               161.0      32.0        0.0
# 3                        Brent                34.0      25.0        1.0
# 4                      Bromley                78.0      44.0        0.0
# 5                       Camden               197.0      46.0        0.0
# 6                      Croydon                47.0       8.0        0.0
# 7                       Ealing                42.0      23.0        1.0
# 8                      Enfield                33.0      13.0        0.0
# 9                    Greenwich                77.0      16.0        1.0
# 10  Hackney and City of London               181.0      58.0        0.0
# 11      Hammersmith and Fulham                55.0      29.0        0.0
# 12                    Haringey                59.0      44.0        0.0
# 13                      Harrow                 7.0      18.0        0.0
# 14                    Havering                35.0       6.0        0.0
# 15                  Hillingdon                 9.0      11.0        0.0
# 16                    Hounslow                24.0      22.0        0.0
# 17                   Islington               106.0      44.0        0.0
# 18      Kensington and Chelsea                71.0      15.0        2.0
# 19        Kingston upon Thames                11.0      15.0        0.0
# 20                     Lambeth                47.0      29.0        1.0
# 21                    Lewisham                67.0      40.0        0.0
# 22                      Merton                32.0      13.0        0.0
# 23                      Newham                45.0      26.0        0.0
# 24                   Redbridge                15.0      11.0        0.0
# 25        Richmond upon Thames                81.0      22.0        0.0
# 26                   Southwark                67.0      47.0        2.0
# 27                      Sutton                 3.0       7.0        0.0
# 28               Tower Hamlets               146.0      73.0        0.0
# 29              Waltham Forest                46.0      15.0        0.0
# 30                  Wandsworth                26.0      27.0        1.0
# 31                 Westminster               210.0      65.0        0.0
#
#     event   food  nightlife  parks_outdoors  shops  travel  \
# 0     0.0   79.0       24.0            22.0   60.0    16.0
# 1     0.0  664.0       82.0           113.0  270.0   107.0
# 2     0.0  479.0      106.0           110.0  235.0    90.0
# 3     0.0  375.0       54.0            55.0  186.0    81.0
# 4     1.0  504.0      135.0            85.0  218.0    81.0
# 5     0.0  860.0      198.0           107.0  252.0   101.0
# 6     0.0  197.0       38.0            60.0  106.0    51.0
# 7     1.0  268.0       53.0            47.0   88.0    43.0
# 8     0.0  189.0       43.0            42.0  110.0    40.0
# 9     0.0  240.0       76.0            68.0  143.0    63.0
# 10    0.0  903.0      287.0           136.0  246.0   101.0
# 11    0.0  480.0       91.0            41.0  170.0    56.0
# 12    0.0  466.0      111.0            72.0  165.0    61.0
# 13    0.0  140.0       16.0            29.0   68.0    22.0
# 14    0.0  209.0       43.0            50.0   91.0    35.0
# 15    0.0  117.0       35.0            15.0   99.0    38.0
# 16    0.0  185.0       44.0            50.0  126.0    66.0
# 17    0.0  782.0      236.0            97.0  181.0    60.0
# 18    0.0  489.0       68.0            45.0  148.0    62.0
# 19    0.0  183.0       49.0            22.0   82.0    27.0
# 20    0.0  441.0      155.0            58.0  105.0    31.0
# 21    0.0  430.0      117.0            70.0  255.0    74.0
# 22    0.0  208.0       40.0            35.0   88.0    41.0
# 23    0.0  232.0       50.0            50.0  164.0    94.0
# 24    1.0  151.0       27.0            18.0  105.0    26.0
# 25    0.0  394.0      109.0           125.0  163.0    69.0
# 26    0.0  510.0      174.0            78.0  153.0    59.0
# 27    0.0   56.0       20.0             9.0   48.0     9.0
# 28    0.0  748.0      187.0           181.0  230.0   117.0
# 29    0.0  182.0       41.0            32.0   80.0    35.0
# 30    0.0  383.0      134.0            36.0  124.0    35.0
# 31    0.0  932.0      174.0           165.0  262.0   192.0
#
#     population_density   GFR
# 0             13952.05  82.6
# 1             11020.84  64.3
# 2             10123.48  63.3
# 3             18997.84  74.5
# 4              5483.85  66.7
# 5             27347.50  41.5
# 6             11156.90  72.5
# 7             15974.53  71.0
# 8             10098.42  68.3
# 9             14442.45  69.1
# 10            34969.97  58.1
# 11            28228.28  52.8
# 12            23063.57  61.5
# 13            12487.02  75.9
# 14             5584.31  68.0
# 15             6420.55  69.0
# 16            12142.85  72.3
# 17            37572.65  44.8
# 18            33246.58  51.7
# 19            11598.96  56.6
# 20            30332.24  48.9
# 21            21089.17  64.7
# 22            13996.07  69.2
# 23            22763.02  73.4
# 24            13235.63  73.4
# 25             8631.71  63.6
# 26            26792.10  53.3
# 27            11572.00  64.8
# 28            35765.40  53.7
# 29            17731.62  75.9
# 30            23470.60  51.6
# 31            27363.21  45.1

# %% [markdown]
# ## Regression models

# %%
joint_boroughs_X = joint_boroughs_df[joint_boroughs_df.columns[1:-1]]
joint_boroughs_Y = joint_boroughs_df['GFR']

# %% [markdown]
# Import modules

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.linear_model import Ridge
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import r2_score as R2
from sklearn.svm import SVR

# %% [markdown]
# Train/test split

# %%
X_train, X_test, y_train, y_test = train_test_split(joint_boroughs_X, joint_boroughs_Y, test_size=0.2, random_state=1)

# %% [markdown]
# Linear and SVR pipelines

# %%
pipe_lr = Pipeline([
        ('scale', StandardScaler()),
        ('pca', PCA(n_components=5)),
        ('regr', Ridge(alpha=50))])

pipe_sv = Pipeline([
        ('scale', StandardScaler()),
        ('pca', PCA(n_components=5)),
        ('regr', SVR(C=1000, gamma=0.1, epsilon=0.1))])

# %% [markdown]
# ### Grid search Ridge pipeline

# %%
parameters_lr = dict(regr__alpha = np.linspace(1, 100))

grid_lr = GridSearchCV (pipe_lr, parameters_lr, cv=5, scoring='r2', return_train_score=False, verbose=1, n_jobs=-1)

grid_lr.fit(X_train, y_train)

print("Best alpha parameter found on training set:")
print()
print(grid_lr.best_params_['regr__alpha'])
cv_results = pd.DataFrame(grid_lr.cv_results_).sort_values(by=['mean_test_score'], ascending=False)
cv_results.drop(list(cv_results.filter(regex = 'params|time|rank_test_score')), axis = 1, inplace = True)
cv_results.head(8)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Done 144 tasks      | elapsed:   15.0s
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:   16.3s finished
# Best alpha parameter found on training set:
#
# 41.4081632653
#     mean_test_score param_regr__alpha  split0_test_score  split1_test_score  \
# 20        -0.474053           41.4082          -0.408544          -0.122435
# 19        -0.474162           39.3878          -0.458497          -0.115182
# 21        -0.474362           43.4286          -0.361860          -0.129256
# 18        -0.474734           37.3673          -0.512045          -0.107443
# 22        -0.475051            45.449          -0.318161          -0.135692
# 17        -0.475819           35.3469          -0.569558          -0.099158
# 23        -0.476083           47.4694          -0.277194          -0.141781
# 24        -0.477428           49.4898          -0.238735          -0.147557
#
#     split2_test_score  split3_test_score  split4_test_score  std_test_score
# 20          -2.706054           0.534788           0.331980        1.164234
# 19          -2.674662           0.539295           0.338235        1.153984
# 21          -2.736906           0.530349           0.325863        1.174790
# 18          -2.642690           0.543869           0.344636        1.144137
# 22          -2.767253           0.525975           0.319878        1.185575
# 17          -2.610082           0.548512           0.351192        1.134808
# 23          -2.797125           0.521666           0.314019        1.196521
# 24          -2.826545           0.517419           0.308280        1.207576

# %% [markdown]
# Let's check R2 score and RMSE on the test set.

# %%
y_lr_pred = grid_lr.predict(X_test)

print('Linear regression RMSE: {} live births per 1,000 women aged 15-44'.format(np.sqrt(MSE(y_test, y_lr_pred)).round(2)))
print('Linear regression R2 score: {}'.format(np.sqrt(R2(y_test, y_lr_pred)).round(2)))
# Out:
# Linear regression RMSE: 7.73 live births per 1,000 women aged 15-44
# Linear regression R2 score: 0.66

# %% [markdown]
# London has GFR of 62.9 ([see here](https://data.london.gov.uk/dataset/births-and-fertility-rates-borough)), hence RMSE of 7.73 is approximately 12.29% error.

# %% [markdown]
# ### SVR randomized parameters search

# %%
parameters_sv = dict(regr__C = np.linspace(0.1, 1000, 10000),
                     regr__gamma = np.linspace(0.1,1000,10000),
                     regr__epsilon = np.linspace(0.0001,1,10000))

rand_sv = RandomizedSearchCV(pipe_sv, param_distributions=parameters_sv, cv=5, random_state=1,
                             scoring='r2', return_train_score=False,  n_iter=10000, verbose=1, n_jobs=-1)
rand_sv.fit(X_train, y_train)

print("Best parameters found on training set:")
print()
print('C={}, gamma={}, epsilon={}'.format(rand_sv.best_params_['regr__C'],
                                          rand_sv.best_params_['regr__gamma'],
                                          rand_sv.best_params_['regr__epsilon']))

cv_results = pd.DataFrame(rand_sv.cv_results_).sort_values(by=['mean_test_score'], ascending=False)
cv_results.drop(list(cv_results.filter(regex = 'params|time|rank_test_score')), axis = 1, inplace = True)
cv_results.head(8)
# Out:
# Fitting 5 folds for each of 10000 candidates, totalling 50000 fits
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 1184 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done 3184 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done 5984 tasks      | elapsed:   18.5s
# [Parallel(n_jobs=-1)]: Done 9584 tasks      | elapsed:   28.9s
# [Parallel(n_jobs=-1)]: Done 13984 tasks      | elapsed:   42.1s
# [Parallel(n_jobs=-1)]: Done 19184 tasks      | elapsed:   57.2s
# [Parallel(n_jobs=-1)]: Done 25184 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 31984 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 39584 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 47984 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 50000 out of 50000 | elapsed:  2.4min finished
# Best parameters found on training set:
#
# C=160.29999999999998, gamma=0.1, epsilon=0.8863
#       mean_test_score param_regr__C param_regr__epsilon param_regr__gamma  \
# 8180        -0.013880         160.3              0.8863               0.1
# 6371        -0.195386          99.6              0.2272               0.4
# 1948        -0.336894         700.6              0.6474               0.1
# 808         -0.432153         241.2              0.5744               0.3
# 9173        -0.507837         897.6              0.3316               0.1
# 7856        -0.726514          32.4              0.0345               0.9
# 9914        -1.078441         591.4              0.0864               5.6
# 1518        -1.078473         998.5              0.2024               5.5
#
#       split0_test_score  split1_test_score  split2_test_score  \
# 8180          -1.632797           0.606946          -0.158797
# 6371          -0.630284           0.229958          -1.235050
# 1948          -1.355771          -1.837411           0.487689
# 808           -0.522285          -0.007914          -2.005398
# 9173          -1.371529          -2.675681           0.500812
# 7856          -0.887116           0.323350          -3.599231
# 9914          -0.280626          -0.319062          -4.733712
# 1518          -0.286367          -0.313136          -4.740024
#
#       split3_test_score  split4_test_score  std_test_score
# 8180           0.755843           0.359405        0.867079
# 6371           0.541160           0.117286        0.646718
# 1948           0.655984           0.365038        1.043850
# 808            0.448654          -0.073824        0.844680
# 9173           0.645104           0.362111        1.307591
# 7856           0.496770           0.033658        1.513591
# 9914           0.104847          -0.163653        1.833640
# 1518           0.106872          -0.159711        1.836807

# %% [markdown]
# R2 score and RMSE on the test set.

# %%
y_sv_pred = rand_sv.predict(X_test)

print('SVR RMSE: {} live births per 1,000 women aged 15-44'.format(np.sqrt(MSE(y_test, y_sv_pred)).round(2)))
print('SVR R2 score: {}'.format(np.sqrt(R2(y_test, y_sv_pred)).round(2)))
# Out:
# SVR RMSE: 6.19 live births per 1,000 women aged 15-44
# SVR R2 score: 0.8

# %% [markdown]
# London has GFR of 62.9 ([see here](https://data.london.gov.uk/dataset/births-and-fertility-rates-borough)), hence RMSE of 6.19 is approximately 9.84% error.
